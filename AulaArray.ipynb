# %%
import numpy as np
import pandas as pd

# %%
dados = np.array([12, 15, 17, 20, 22, 25, 28, 30, 35, 40])
mediana= np.median(dados)
q1 = np.percentile(dados, 25)
q2 = np.percentile(dados, 50)
q3 = np.percentile(dados, 75)
print (f'Primeiro quartil (Q1): {q1}')
print (f'Segundo quartil (Q2, Mediana): {q2}')
print(f'Mediana: {mediana}')
print (f'Terceiro quartil (Q3): {q3}')
# Out:
# Primeiro quartil (Q1): 17.75
# Segundo quartil (Q2, Mediana): 23.5
# Mediana: 23.5
# Terceiro quartil (Q3): 29.5

# %%
pesquisa = pd.read_csv('pesquisa_satisfacao.csv', sep=";")
pesquisa
# Out:
#          Cliente Satisfação  Tempo de Espera (min)
# 0         Naruto       Alta                      8
# 1           Goku       Alta                     10
# 2         Vegeta      Média                     17
# 3         Sasuke       Alta                      8
# 4         Madara      Média                     15
# 5          Luffy      Baixa                      5
# 6           Zoro       Alta                     22
# 7          Sanji      Baixa                     26
# 8         Yusuke      Baixa                     14
# 9         Kurama      Média                      8
# 10           Gon      Média                     12
# 11          Eren      Média                     28
# 12        Mikasa       Alta                      6
# 13         Light       Alta                     10
# 14             L       Alta                     19
# 15  Peter Parker      Baixa                     21
# 16   Bruce Wayne       Alta                     18
# 17        Thanos      Média                     19
# 18       Edmundo      Baixa                     13
# 19       Vegetti      Média                     19

# %%
tempo_espera_array = np.array(pesquisa["Tempo de Espera (min)"])

# %%
mediana= np.median(tempo_espera_array)
q1 = np.percentile(tempo_espera_array, 25)
q2 = np.percentile(tempo_espera_array, 50)
q3 = np.percentile(tempo_espera_array, 75)
print (f'Primeiro quartil (Q1): {q1}')
print (f'Segundo quartil (Q2, Mediana): {q2}')
print(f'Mediana: {mediana}')
print (f'Terceiro quartil (Q3): {q3}')
# Out:
# Primeiro quartil (Q1): 9.5
# Segundo quartil (Q2, Mediana): 14.5
# Mediana: 14.5
# Terceiro quartil (Q3): 19.0

# %%
pesquisa_maiores = pesquisa.loc[pesquisa['Tempo de Espera (min)']>= q3]
pesquisa_maiores
# Out:
#          Cliente Satisfação  Tempo de Espera (min)
# 6           Zoro       Alta                     22
# 7          Sanji      Baixa                     26
# 11          Eren      Média                     28
# 14             L       Alta                     19
# 15  Peter Parker      Baixa                     21
# 17        Thanos      Média                     19
# 19       Vegetti      Média                     19

# %%
pesquisa.sort_values(by="Tempo de Espera (min)", ascending= False) #Maior para o menor
# Out:
#          Cliente Satisfação  Tempo de Espera (min)
# 11          Eren      Média                     28
# 7          Sanji      Baixa                     26
# 6           Zoro       Alta                     22
# 15  Peter Parker      Baixa                     21
# 17        Thanos      Média                     19
# 19       Vegetti      Média                     19
# 14             L       Alta                     19
# 16   Bruce Wayne       Alta                     18
# 2         Vegeta      Média                     17
# 4         Madara      Média                     15
# 8         Yusuke      Baixa                     14
# 18       Edmundo      Baixa                     13
# 10           Gon      Média                     12
# 13         Light       Alta                     10
# 1           Goku       Alta                     10
# 0         Naruto       Alta                      8
# 3         Sasuke       Alta                      8
# 9         Kurama      Média                      8
# 12        Mikasa       Alta                      6
# 5          Luffy      Baixa                      5

# %%
satisfacao = np.array(pesquisa["Satisfação"])

# %%
pesquisa_alta = pesquisa.loc[pesquisa['Satisfação'] == 'Alta']
pesquisa_alta
# Out:
#         Cliente Satisfação  Tempo de Espera (min)
# 0        Naruto       Alta                      8
# 1          Goku       Alta                     10
# 3        Sasuke       Alta                      8
# 6          Zoro       Alta                     22
# 12       Mikasa       Alta                      6
# 13        Light       Alta                     10
# 14            L       Alta                     19
# 16  Bruce Wayne       Alta                     18

# %%
array_alta = np.array(pesquisa_alta['Tempo de Espera (min)'])
array_alta
# Out:
# array([ 8, 10,  8, 22,  6, 10, 19, 18])

# %%
mediana_geral= np.median(array_alta)
q1_geral = np.percentile(array_alta, 25)
q2_geral = np.percentile(array_alta, 50)
q3_geral = np.percentile(array_alta, 75)
print (f'Primeiro quartil (Q1): {q1_geral}')
print (f'Segundo quartil (Q2, Mediana): {q2_geral}')
print(f'Mediana: {mediana_geral}')
print (f'Terceiro quartil (Q3): {q3_geral}')
# Out:
# Primeiro quartil (Q1): 8.0
# Segundo quartil (Q2, Mediana): 10.0
# Mediana: 10.0
# Terceiro quartil (Q3): 18.25

# %%
mediana= np.median(array_alta)
q1 = np.percentile(array_alta, 25)
q2 = np.percentile(array_alta, 50)
q3 = np.percentile(array_alta, 75)
print (f'Primeiro quartil (Q1): {q1}')
print (f'Segundo quartil (Q2, Mediana): {q2}')
print(f'Mediana: {mediana}')
print (f'Terceiro quartil (Q3): {q3}')
# Out:
# Primeiro quartil (Q1): 8.0
# Segundo quartil (Q2, Mediana): 10.0
# Mediana: 10.0
# Terceiro quartil (Q3): 18.25
